# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:04952afc-2665-4cd2-be5a-2b2e7cc0a723.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name = 'Node1'
node2_name = 'Node2'
network_name='net1'
node1_nic_name = 'nic1'
node1_nic_model = 'NIC_Basic'
node2_nic_name = 'nic2'
node2_nic_model = 'NIC_Basic'
# Value left as '' for random sites in define_slice.ipynb. If specified, e.g, 'CLEM', the value will be used.
node1_site = ''
node2_site = ''
subnet = IPv4Network("192.168.1.0/24")
# Value left as '' for the first available in config_slice.ipynb. 
# If specified, e.g, '192.168.1.2', the value will be used. Make sure the value is in the subnet
node1_addr = ''
node2_addr = ''
