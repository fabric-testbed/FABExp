# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:1755626b-f1fc-425d-b91c-3c17893a4b02.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name = 'Node1'
node1_cores = 4
node1_ram = 16
node1_disk =50
node1_nic_name = 'nic_local'
node1_nic_model = 'NIC_Basic'


node2_name = 'Node2'
node2_cores = 4
node2_ram = 16
node2_disk = 50
node2_nic_name = 'nic_local'
node2_nic_model = 'NIC_Basic'

node3_name = 'bridge1'
node3_nic_name = 'nic_local'
node3_nic_model = 'NIC_ConnectX_5'
node3_cores = 4
node3_ram = 16
node3_disk =50

default_image= 'default_ubuntu_22'

# Value left as '' for random sites in define_slice.ipynb. If specified, the value will be used.
node1_site = ''
node2_site = ''
node3_site = ''
