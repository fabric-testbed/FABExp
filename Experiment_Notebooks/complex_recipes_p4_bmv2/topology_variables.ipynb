# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:3c274c5e-4ddc-4f89-8a56-e719805b4a1b.png)

# %% [markdown]
# # Topology Variables

# %%
# Switches
s1_name = "s1"
s1_nic1_name = "s1_local_nic"
s1_nic2_name = "s1_switch_nic1"
s1_nic3_name = "s1_switch_nic2"

s2_name = "s2"
s2_nic1_name = "s2_local_nic"
s2_nic2_name = "s2_switch_nic1"
s2_nic3_name = "s2_switch_nic2"

s3_name = "s3"
s3_nic1_name = "s3_local_nic"
s3_nic2_name = "s3_switch_nic1"
s3_nic3_name = "s3_switch_nic2"

switch_cores = 2
switch_ram = 8
switch_disk = 100

# Hosts
h1_name = "h1"
h1_nic_name = "h1_nic"

h2_name = "h2"
h2_nic_name = "h2_nic"

h3_name = "h3"
h3_nic_name = "h3_nic"

h1_subnet=IPv4Network('10.0.1.0/24')
h1_addr=IPv4Address('10.0.1.1')

h2_subnet=IPv4Network('10.0.2.0/24')
h2_addr=IPv4Address('10.0.2.2')

h3_subnet=IPv4Network('10.0.3.0/24')
h3_addr=IPv4Address('10.0.3.3')

host_cores = 2
host_ram = 8
host_disk = 10

net_h1_name = 'net_h1'
net_h2_name = 'net_h2'
net_h3_name = 'net_h3'

net_s1_s2_name = 'net_s1_s2'
net_s2_s3_name = 'net_s2_s3'
net_s1_s3_name = 'net_s1_s3'

# left as '' for random sites in define_slice.ipynb
s1_site = ''
s2_site = ''
s3_site = ''
h1_site = ''
h2_site = ''
h3_site = ''

# All node properties
image = 'default_ubuntu_20'
nic_model = 'NIC_Basic'
