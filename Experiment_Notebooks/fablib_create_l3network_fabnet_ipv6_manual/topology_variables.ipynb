# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:21480c25-cad5-4a07-9876-c0b6437720ed.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name = 'Node1'
node2_name = 'Node2'
network1_name='net1'
network1_type = 'IPv6'
network2_name='net2'
network2_type = 'IPv6'
node1_nic_name = 'nic1'
node1_nic_model = 'NIC_Basic'
node2_nic_name = 'nic2'
node2_nic_model = 'NIC_Basic'
# Value left as '' for random sites in define_slice.ipynb. If specified, e.g, 'CLEM', the value will be used.
node1_site = ''
node2_site = ''
# Value left as '' for the first available in config_slice.ipynb. 
node1_addr = ''
node2_addr = ''
