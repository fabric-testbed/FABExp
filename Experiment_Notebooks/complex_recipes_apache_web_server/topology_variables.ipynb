# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:59b4fd4d-795f-418a-8593-380e93feac70.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name = 'server'
node2_name = 'client'
network1_name='net1'
node1_nic_name = 'server_nic'
node2_nic_name = 'client_nic'
node1_nic_model='NIC_Basic'
node2_nic_model='NIC_Basic'

# We will use Ubuntu 20.04 for both nodes
image = 'default_ubuntu_20'

# Value left as '' for random sites in define_slice.ipynb. If specified, e.g, 'CLEM', the value will be used.
node1_site = ''
node2_site = ''

subnet1 = IPv4Network("192.168.1.0/24")
