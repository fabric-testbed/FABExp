# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:8be56cb6-405a-4160-9d86-99fb3d7397d5.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name='Node1'
