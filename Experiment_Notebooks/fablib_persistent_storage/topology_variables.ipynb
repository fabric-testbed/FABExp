# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:b41443b2-bab6-47d3-bbbe-bc8a1c4922d3.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name = 'Node1'
node1_storage_name = f'FABRIC_Staff_star_50G_1'
# You can specify values, e.g, 'CLEM'
node1_site = 'STAR'
