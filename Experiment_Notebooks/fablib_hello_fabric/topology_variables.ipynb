# %% [markdown]
# # Slice Topology

# %% [markdown]
# ![image.png](attachment:9c9db6cc-ccee-4567-939c-28a27b333431.png)

# %% [markdown]
# # Topology Variables

# %%
# topology variables 
node1_name='Node1'
